# %%
{
 "cells": [
  {
   "cell_type": "code",
   "execution_count": 17,
   "metadata": {
    "collapsed": true
   },
   "outputs": [],
   "source": [
    "import gzip\n",
    "import gensim \n",
    "import logging\n",
    "logging.basicConfig(level=logging.DEBUG)\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 5,
   "metadata": {
    "collapsed": true
   },
   "outputs": [],
   "source": [
    "def read_input(input_file):\n",
    "\t\"\"\"This method reads the input file which is in gzip format\"\"\"\n",
    "\t\n",
    "\tlogging.info(\"reading file {0}...this may take a while\".format(input_file))\n",
    "\t\n",
    "\twith gzip.open (input_file, 'rb') as f:\n",
    "\t\tfor i, line in enumerate (f): \n",
    "\n",
    "\t\t\tif (i%10000==0):\n",
    "\t\t\t\tlogging.info (\"read {0} reviews\".format (i))\n",
    "\t\t\t# do some pre-processing and return a list of words for each review text\n",
    "\t\t\tyield gensim.utils.simple_preprocess (line)\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 9,
   "metadata": {
    "collapsed": false
   },
   "outputs": [
    {
     "name": "stdout",
     "output_type": "stream",
     "text": [
      "10\n"
     ]
    }
   ],
   "source": [
    "a=10\n",
    "print a"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 18,
   "metadata": {
    "collapsed": false
   },
   "outputs": [
    {
     "name": "stdout",
     "output_type": "stream",
     "text": [
      "Done reading data file\n"
     ]
    }
   ],
   "source": [
    "documents = list (read_input (\"reviews_data.txt.gz\"))\n",
    "print \"Done reading data file\""
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 19,
   "metadata": {
    "collapsed": false
   },
   "outputs": [
    {
     "name": "stderr",
     "output_type": "stream",
     "text": [
      "WARNING:gensim.models.base_any2vec:Effective 'alpha' higher than previous training cycles\n"
     ]
    },
    {
     "name": "stdout",
     "output_type": "stream",
     "text": [
      "Training model\n",
      "Model trained\n"
     ]
    }
   ],
   "source": [
    "model = gensim.models.Word2Vec (documents, size=100, window=10, min_count=2, workers=10)\n",
    "print \"Training model\"\n",
    "model.train(documents,total_examples=len(documents),epochs=10)\n",
    "print \"Model trained\""
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 14,
   "metadata": {
    "collapsed": false
   },
   "outputs": [
    {
     "name": "stdout",
     "output_type": "stream",
     "text": [
      "[(u'filthy', 0.8605918288230896), (u'unclean', 0.7872298955917358), (u'stained', 0.7809049487113953), (u'dusty', 0.7737701535224915), (u'grubby', 0.7640288472175598), (u'smelly', 0.7638705968856812), (u'dingy', 0.7330941557884216), (u'gross', 0.7314556837081909), (u'disgusting', 0.711143970489502), (u'grimy', 0.7108157277107239)]\n"
     ]
    }
   ],
   "source": [
    "w1 = \"dirty\"\n",
    "print model.wv.most_similar (positive=w1)"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 22,
   "metadata": {
    "collapsed": false
   },
   "outputs": [
    {
     "name": "stdout",
     "output_type": "stream",
     "text": [
      "[ -2.19303086e-01  -2.88474411e-02  -8.11420250e+00   2.83480191e+00\n",
      "  -1.35823917e+00   1.56496143e+00  -2.11412811e+00  -1.62608135e+00\n",
      "   1.57304680e+00   1.30592442e+00  -3.51201391e+00   4.09215689e-01\n",
      "  -2.68659759e+00   1.29351676e+00  -1.57445872e+00   5.18705882e-02\n",
      "  -1.78067422e+00  -6.56598377e+00  -9.09853399e-01  -1.96509421e+00\n",
      "   2.41910005e+00   9.83066320e-01   7.38306880e-01  -3.03441143e+00\n",
      "  -3.46890062e-01   2.12788367e+00   3.04096246e+00   6.02690220e-01\n",
      "   4.34922743e+00   2.05738497e+00   6.58910370e+00   1.44861686e+00\n",
      "   2.99755168e+00  -1.20672274e+00  -1.70791793e+00  -5.29811907e+00\n",
      "  -3.61028242e+00   2.15190387e+00  -8.76770794e-01   2.16893077e-01\n",
      "  -1.92470384e+00  -1.39617062e+00   1.45718467e+00  -3.35419118e-01\n",
      "  -1.89717567e+00   1.49699616e+00  -1.50018942e+00  -5.36821038e-02\n",
      "  -4.08865422e-01   2.79571116e-01   3.93044472e+00   2.92954922e-01\n",
      "  -1.75992060e+00   4.83922958e+00   7.18770549e-03  -2.03018188e+00\n",
      "   3.15000486e+00   2.04503608e+00   3.13388586e+00   3.07883203e-01\n",
      "  -2.27254295e+00  -7.57412195e-01  -2.04093289e+00  -3.46738839e+00\n",
      "   2.60640979e+00   6.26769483e-01  -1.53049171e+00  -3.69118118e+00\n",
      "  -4.08453703e-01  -3.10141873e+00  -4.34588134e-01  -4.76577431e-01\n",
      "  -1.75007510e+00  -2.43567204e+00  -1.76848733e+00   4.33461070e-01\n",
      "   2.10797501e+00  -1.50509930e+00  -9.59908366e-01   4.31083679e+00\n",
      "   7.25064468e+00  -1.97127008e+00  -1.16364408e+00  -3.66479850e+00\n",
      "   6.77183032e-01  -5.17210531e+00  -4.88205814e+00   4.87751454e-01\n",
      "  -3.10203743e+00  -4.99226183e-01  -2.41884559e-01   1.21832609e+00\n",
      "  -7.90648580e-01   4.80678082e+00  -1.22414458e+00  -5.98880386e+00\n",
      "   3.12212016e-02   2.12671232e+00  -3.14978933e+00  -1.26722567e-02]\n"
     ]
    }
   ],
   "source": [
    "print model['dirty']\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 23,
   "metadata": {
    "collapsed": false
   },
   "outputs": [
    {
     "name": "stdout",
     "output_type": "stream",
     "text": [
      "[(u'germany', 0.7070611119270325), (u'canada', 0.6965396404266357), (u'spain', 0.6817945241928101), (u'england', 0.6776233315467834), (u'mexico', 0.6762300133705139), (u'hawaii', 0.6679205298423767)]\n"
     ]
    }
   ],
   "source": [
    "w1 = \"france\"\n",
    "print model.wv.most_similar (positive=w1,topn=6)"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 20,
   "metadata": {
    "collapsed": false
   },
   "outputs": [
    {
     "name": "stdout",
     "output_type": "stream",
     "text": [
      "[(u'filthy', 0.9009050130844116), (u'grubby', 0.8204491138458252), (u'stained', 0.8147488832473755), (u'unclean', 0.8146927356719971), (u'dusty', 0.8088377714157104), (u'smelly', 0.7869859933853149), (u'grimy', 0.78697669506073), (u'dingy', 0.7593576908111572), (u'gross', 0.7569754719734192), (u'mouldy', 0.7518353462219238)]\n"
     ]
    }
   ],
   "source": [
    "w1 = \"dirty\"\n",
    "print model.wv.most_similar (positive=w1)"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 24,
   "metadata": {
    "collapsed": false
   },
   "outputs": [
    {
     "name": "stdout",
     "output_type": "stream",
     "text": [
      "0.301145\n"
     ]
    }
   ],
   "source": [
    "w1 = \"dirty\"\n",
    "w2  =\"clean\"\n",
    "print model.wv.similarity (w1,w2)"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 25,
   "metadata": {
    "collapsed": false
   },
   "outputs": [
    {
     "name": "stdout",
     "output_type": "stream",
     "text": [
      "[(u'blue', 0.684958815574646), (u'green', 0.6125293970108032), (u'gray', 0.60820472240448), (u'formations', 0.5741811394691467), (u'white', 0.5191130042076111), (u'neon', 0.5061995387077332)]\n"
     ]
    }
   ],
   "source": [
    "w1 = \"red\"\n",
    "print model.wv.most_similar (positive=w1,topn=6)"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 26,
   "metadata": {
    "collapsed": true
   },
   "outputs": [],
   "source": [
    "import pickle"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 27,
   "metadata": {
    "collapsed": true
   },
   "outputs": [],
   "source": [
    "fileObject = open(\"modelogensim\",'wb') "
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 28,
   "metadata": {
    "collapsed": true
   },
   "outputs": [],
   "source": [
    "pickle.dump(model,fileObject) "
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 30,
   "metadata": {
    "collapsed": true
   },
   "outputs": [],
   "source": [
    "fileObject.close()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 31,
   "metadata": {
    "collapsed": true
   },
   "outputs": [],
   "source": [
    "fileObject = open(\"modelogensim\",'r')  \n",
    "# load the object from the file into var b\n",
    "b = pickle.load(fileObject)"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 32,
   "metadata": {
    "collapsed": false
   },
   "outputs": [
    {
     "name": "stdout",
     "output_type": "stream",
     "text": [
      "[(u'blue', 0.6849587559700012), (u'green', 0.612529456615448), (u'gray', 0.60820472240448), (u'formations', 0.5741811394691467), (u'white', 0.5191129446029663), (u'neon', 0.5061995387077332)]\n"
     ]
    }
   ],
   "source": [
    "print b.wv.most_similar (positive=w1,topn=6)"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 34,
   "metadata": {
    "collapsed": false
   },
   "outputs": [],
   "source": [
    "a = b.wv.most_similar(positive=w1,topn=6)"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 37,
   "metadata": {
    "collapsed": false
   },
   "outputs": [
    {
     "data": {
      "text/plain": [
       "0.612529456615448"
      ]
     },
     "execution_count": 37,
     "metadata": {},
     "output_type": "execute_result"
    }
   ],
   "source": [
    "a[1][1]"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {
    "collapsed": true
   },
   "outputs": [],
   "source": []
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 2",
   "language": "python",
   "name": "python2"
  },
  "language_info": {
   "codemirror_mode": {
    "name": "ipython",
    "version": 2
   },
   "file_extension": ".py",
   "mimetype": "text/x-python",
   "name": "python",
   "nbconvert_exporter": "python",
   "pygments_lexer": "ipython2",
   "version": "2.7.10"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 0
}
